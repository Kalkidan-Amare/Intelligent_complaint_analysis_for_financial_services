# %% [markdown]
# # Task 2 — Sample Chunking, Embedding, and Chroma Indexing
#
# This notebook runs Task 2 on a stratified sample (10k–15k) from `data/filtered_complaints.csv`.
#
# It persists a ChromaDB vector store into `vector_store/sample_chroma/`.
#
# Note: the canonical implementation is the CLI: `python -m src.embeddings.index_sample ...`

# %%
import pandas as pd
from pathlib import Path

from src.embeddings.index_sample import build_sample_index

df = pd.read_csv('data/filtered_complaints.csv')
persist_dir = Path('vector_store/sample_chroma')

info = build_sample_index(df, persist_dir=persist_dir, sample_size=12000)
info
